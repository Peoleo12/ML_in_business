# %%
# !pip install dill
# Out:
# Collecting dill
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: dill
# Successfully installed dill-0.3.7

# %%
import pandas as pd
from sklearn.metrics import r2_score
import dill
dill._dill._reverse_typemap['ClassType'] = type

# %%
X_test = pd.read_csv("/content/X_test.csv")
y_test = pd.read_csv("/content/y_test.csv")

# %%
X_test.head()
# Out:
#    DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# 0          22    1.0  42.794118   27.816177            3.0     11        17.0
# 1          11    1.0  42.535158   21.921874            8.0      7         9.0
# 2         122    3.0  75.222209   46.157077           10.0     10        14.0
# 3           6    3.0  79.516816   75.867773            3.0      7        25.0
# 4          23    1.0  34.913284   22.693634            3.0      3        15.0
#
#    HouseYear  Ecology_1  Social_1  ...  Rooms_outlier  HouseFloor_outlier  \
# 0       1977   0.118537        30  ...              0                   0
# 1       1987   0.012339        35  ...              0                   0
# 2       1996   0.033494        66  ...              0                   0
# 3       2016   0.243205         5  ...              0                   0
# 4       1977   0.005767         1  ...              0                   0
#
#    HouseYear_outlier  LifeSquare_nan  Ecology_2_A  Ecology_2_B  Ecology_3_A  \
# 0                  0               1            0            1            0
# 1                  0               0            0            1            0
# 2                  0               0            0            1            0
# 3                  0               0            0            1            0
# 4                  0               1            0            1            0
#
#    Ecology_3_B  Shops_2_A  Shops_2_B
# 0            1          0          1
# 1            1          0          1
# 2            1          0          1
# 3            1          0          1
# 4            1          0          1
#
# [5 rows x 24 columns]

# %%
FEATURES = ['DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare', 'Floor', 'HouseFloor', 'HouseYear']

# %%
X_test = X_test[FEATURES]

# %%
with open('/content/model.dill', 'rb') as in_strm:
    model = dill.load(in_strm)

# %%
predictions = model.predict(X_test.iloc[:500])

# %%
pd.DataFrame({'preds':predictions}).to_csv("test_predictions.csv", index=None)

# %%
r2_score(y_true=y_test.iloc[:500], y_pred=predictions)
# Out:
# 0.7024953361576929
